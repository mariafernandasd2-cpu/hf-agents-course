# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool, InferenceClientModel

# %%
agent = CodeAgent(
    tools=[DuckDuckGoSearchTool()],
    model=InferenceClientModel()
)

response = agent.run(
    "Search for luxury superhero party ideas and summarize them."
)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Search for luxury superhero party ideas and summarize them.                                                     │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen3-Next-80B-A3B-Thinking ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   web_results = web_search(query="luxury superhero party ideas")
#   print(web_results)
# ...

# %%
print(response)
# Out:
# Luxury superhero parties emphasize upscale design and exclusive experiences. Key elements include custom decor with premium materials (e.g., metallic balloons, velvet backdrops), gourmet themed food and cocktails, professional event styling, and personalized activities like custom cape-making with silk fabrics. Themed photo booths with high-end props, Avengers-inspired setups with gold accents, and luxury party favors such as engraved superhero medals are also popular. Events often feature professional designers to ensure a cohesive, high-end atmosphere.
