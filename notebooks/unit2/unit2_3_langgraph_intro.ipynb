# %%
# %pip install langgraph langchain langchain_openai
# Out:
# ...
#      ---------------------------------------- 0.0/43.1 kB ? eta -:--:--
#      ---------------------------------------- 43.1/43.1 kB 2.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/234.3 kB ? eta -:--:--
#    --------------------------------------- 234.3/234.3 kB 14.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/114.3 kB ? eta -:--:--
#    ---------------------------------------- 114.3/114.3 kB 6.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/98.6 kB ? eta -:--:--
#    ---------------------------------------- 98.6/98.6 kB 5.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/548.1 kB ? eta -:--:--
#    --------------------------------------- 548.1/548.1 kB 17.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/56.0 kB ? eta -:--:--
#    ---------------------------------------- 56.0/56.0 kB 2.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/41.0 kB ? eta -:--:--
# ...

# %%
from langgraph.graph import StateGraph, START, END

print("LangGraph instalado correctamente")
# Out:
# LangGraph instalado correctamente
