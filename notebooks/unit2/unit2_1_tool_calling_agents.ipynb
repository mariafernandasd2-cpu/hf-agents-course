# %%
from smolagents import ToolCallingAgent, DuckDuckGoSearchTool, InferenceClientModel

model = InferenceClientModel(
    model_id="Qwen/Qwen2.5-72B-Instruct"
)

agent = ToolCallingAgent(
    tools=[DuckDuckGoSearchTool()],
    model=model
)

result = agent.run(
    "Search for party music recommendations."
)

print(result)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Search for party music recommendations.                                                                         │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen2.5-72B-Instruct ──────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'web_search' with arguments: {'query': 'party music recommendations'}                             │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Observations: ## Search Results
#
# |Good music for a party? - FoodAQ](https://foodaq.com/html/Entertaining/293023.html)
# I am 20, and the best music for parties are techno, electro, dance, hip-hop, rnb, but i recommend mostly dance and
# techno, it will have all of you ...
#
# |Party Music Guide: Ultimate Tips for the Perfect Playlist
# |](https://thebackstage-deezer.com/music/perfect-party-music-playlist/)
# We recommend you get at least three hours’ worth of party music queued and ready — that ’ s about 75 songs.
#
# |Best Party Songs — Best Dance
# Music](https://www.cosmopolitan.com/entertainment/music/a31046206/best-songs-for-party-playlist/)
# Demi threw an actual party for this song's music video, so it's easy to see how it fits into any party's playlist.
# ... when Blair Waldorf had a music ...
#
# |Staimusic - Discover the Best Party Songs
# Playlist](https://www.staimusic.com/en/playlists/making-a-party-in-american-universities_44.html)
# Let's make some unforgettable memories at this one of a kind event! Listen to a playlist of party songs, a mix of
# dance music and disco songs to have ...
#
# |Party music...? - General Chat - Metal Forum](https://metalforum.com/topic/7467-party-music/)
# Re: Party music...? Just to be a dick towards the non-metallers Dimmu borgir-Når sjelen hentes til helvette The
# entire Stormblast album infact.
#
# |Best Ways To Listen To Music – Jayandmarvin.com](https://www.jayandmarvin.com/best-ways-to-listen-to-music/)
# Music has long been associated with party ’ s, particularly dance music , whether it be a late night dancing
# session in a nightclub or a high ...
#
# |Music History – Jayandmarvin.com](https://www.jayandmarvin.com/category/music-history/)
# Whatever form of the music industry you participate in, it is essential that you look after your health and
# wellbeing as well as the inevitable ...
#
# |27 Best Party Songs For Kids, All Clean and Dance Worthy
# -](https://www.musicindustryhowto.com/party-songs-for-kids/)
# Spread the love Whether hosting a birthday, wedding, or New Year party, you need epic music to kick the party into
# life.
#
# |Party Music | Best Ways to get your Party Started - The
# Event](https://theeventbook.co.uk/party-music-best-ways-to-get-your-party-started/)
# That ’ s why it is really important to check first if you can actually play the music you ’ re planning to at your
# party.
#
# |Best music for parties – RapReviews](https://www.rapreviews.com/2022/06/best-music-for-parties/)
# ... makes it impossible to stand still! The unexpected duo of Bruno Mars and Cardi B have created a work that
# deserves to be at the top of all parties.
# [Step 1: Duration 4.00 seconds| Input tokens: 1,139 | Output tokens: 19]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'final_answer' with arguments: {'answer': 'Based on the search results, here are some music genre │
# │ recommendations for parties: \n- Techno\n- Electro\n- Dance\n- Hip-Hop\n- R&B\nAdditionally, it is recommended  │
# │ to have a playlist of around 75 songs, which would cover about 3 hours of music.'}                              │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Observations: Based on the search results, here are some music genre recommendations for parties:
# - Techno
# - Electro
# - Dance
# - Hip-Hop
# - R&B
# Additionally, it is recommended to have a playlist of around 75 songs, which would cover about 3 hours of music.
# Final answer: Based on the search results, here are some music genre recommendations for parties:
# - Techno
# - Electro
# - Dance
# - Hip-Hop
# - R&B
# Additionally, it is recommended to have a playlist of around 75 songs, which would cover about 3 hours of music.
# [Step 2: Duration 2.96 seconds| Input tokens: 2,990 | Output tokens: 97]
# Based on the search results, here are some music genre recommendations for parties:
# - Techno
# - Electro
# - Dance
# - Hip-Hop
# - R&B
# Additionally, it is recommended to have a playlist of around 75 songs, which would cover about 3 hours of music.
